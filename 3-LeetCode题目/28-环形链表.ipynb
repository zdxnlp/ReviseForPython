# %% [markdown]
# ![image.png](attachment:6b9b23e3-ca50-4bf8-a898-fdbd90541e04.png)

# %%
from typing import Optional


class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        if not head:
            return False
        else:
            if head.next is None:
                return False
        maxlen = 0
        pos = head
        while pos:
            maxlen += 1
            pos = pos.next
        currentlen = 0
        while head:
            currentlen += 1
            head = head.next
            if currentlen > maxlen:
                return True
        return False

# %% [markdown]
# - 上面的问题是我拿不到真实的长度，第一次遍历就会进入死循环
# - 快慢指针，如果走的快的碰到走的慢的，说明就存在环

# %%
class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        if not head:
            return False
        else:
            if head.next is None:
                return False
        slow = head
        fast = head.next
        while fast:
            if fast == slow:
                return True
            else:
                slow = slow.next
                if fast.next:
                    fast = fast.next
                    if fast.next:
                        fast = fast.next
                else:
                    return False
        return False
